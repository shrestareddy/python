# %% [markdown]
# #Markdowns
# ##Markdowns
# ###Markdowns
# ####Markdowns

# %% [markdown]
# insert site address

# %% [markdown]
# [site](https://www.anaconda.com/distribution/)

# %% [markdown]
# #insert image address

# %% [markdown]
# ![text](https://image.shutterstock.com/image-photo/spring-blossom-background-beautiful-nature-260nw-1033292395.jpg)

# %% [markdown]
# #Python Basics:
# python is beginners language
#
#
# python is easy to learn

# %% [markdown]
# #create  ordered list
# 1.abc
#
# 2.hsbf
#    1. a
#    2. b

# %% [markdown]
# #create unordered list
# - abdc
#
# - hsb
#
#     - a
#     - b

# %% [markdown]
# ## Bold and Italics
# **GITAM**
# *GITAM*

# %%
#BASIC HELLO PROGRAM
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
#variable creation
x=4 
y=5
x+y
# Out:
# 9

# %% [markdown]
# #rules for variable
# - names should begin with a character
#
# - no special character allowed except _

# %%
name="shresta"
age="19"
print("my name is:",name,"my age is",age)
# Out:
# my name is: shresta my age is 19

# %%
name=input("enter name")
age=int (input("enter age"))
print("my name is:",name,"my age is:",age)
# Out:
# enter nameshresta
# enter age19
# my name is: shresta my age is: 19

# %%
x=int(input("enter a number"))
y=int(input("enter a number"))
print("addition is:",x+y)

print("sub is:",x-y)

print("multiplcation is:",x*y)

print("division is:",x/y)
# Out:
# enter a number5
# enter a number4
# addition is: 9
# sub is: 1
# multiplcation is: 20
# division is: 1.25

# %% [markdown]
# #Fundamental Datatypes
# - int
# - float
# - complex
# - boolean
# - string

# %%
x = 10
y = 12.32
z = 5+6j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c = complex(5,10)
print(c)
# Out:
# (5+10j)

# %%
c1 = 2+4j
c2 =3+6j
print(c1+c2)
print(c1-c2)
print(c1*c2)
# Out:
# (5+10j)
# (-1-2j)
# (-18+24j)

# %%
a = 10
b = 5
a < b
# Out:
# False

# %%
# string
s1 = "abc"
s2 = "def"
print(type(s1),type(s2))
# Out:
# <class 'str'> <class 'str'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
f1=float
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'type'>

# %%
# length of string
a = "abcd"
print(len(str(a)))
# Out:
# 4

# %%
n=19
a=b=c=20
a1,b1,c1=1,2,3
print(n)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 19
# 20 20 20
# 1 2 3

# %% [markdown]
#  # precedence of the arth operators
#  - parenthesis
#  - power
#  - multiplication
#  - addition

# %%
x = 1+2 ** 3 /  4+ 5
print(x)
# Out:
# 8.0

# %%
x = 1+2 **3/4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# # operators
# ## Arithematic operators
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %%
x = int (input("enter a value"))
y = int (input("enter a value"))
print("addition is:",x+y)
print("sub is:",x-y)
print("multiplcation is:",x*y)
print("division is:",x/y)
print("reminder",x%y)
print("power",x**y)
print("quotient",x//y)
# Out:
# enter a value10
# enter a value4
# addition is: 14
# sub is: 6
# multiplcation is: 40
# division is: 2.5
# reminder 2
# power 10000
# quotient 2

# %% [markdown]
# #Relational operators
# - ==,!=,<,>,<=,>=

# %%
x = 5
a = x > 10
print(a)
# Out:
# False

# %% [markdown]
# # Logical operators
# - and
# - or
# - not

# %%
i= 100
a1 =( i > 15) and (i>76)
a2 =(i> 15) and (i>100)
a3 =( i > 15) or (i>76)
a4 =(i> 15) or (i>100)
print(a1)
print(a2)
print(a3)
print(a4)
print(not i)
# Out:
# True
# False
# True
# True
# False

# %% [markdown]
# # Membership Operator
# - in
# - not in

# %%
str1="abc"
print('a' in str1)
print('a' not in str1)
# Out:
# True
# False

# %% [markdown]
# #Conditional Statements
# - conditional statements
# - looping statements
# - if - else statement
# -- Syntax
#
#    ######if condition:
#     > statement<br>
#    ##### else:
#    > statements

# %%
# check given is odd or even
n = int(input("enter a number"))
if n%2==0:
  print("even")
else :
  print("odd")
# Out:
# enter a number10
# even

# %%
# check given number is perfect multiple of 3 and 5
n = int(input("enter a number"))
if n%3==0 and n%5==0 :
  print("yes")
else :
    print("no")
# Out:
# enter a number15
# yes

# %%
# check + or - or zero
n = int(input("enter a number"))
if n>0:
   print ("pos")
elif(n<0):
  print("neg")
else:
  print("0")
# Out:
# enter a number2
# pos

# %%
# check input here is leap year or not
